# %%
import sys
import torch
pyt_version_str=torch.__version__.split("+")[0].replace(".", "")
version_str="".join([
    f"py3{sys.version_info.minor}_cu",
    torch.version.cuda.replace(".",""),
    f"_pyt{pyt_version_str}"
])

# %%
# !pip install iopath
# !pip install --no-index --no-cache-dir pytorch3d -f https://dl.fbaipublicfiles.com/pytorch3d/packaging/wheels/{version_str}/download.html
# Out:
# Collecting iopath
#   Using cached iopath-0.1.10-py3-none-any.whl
# Requirement already satisfied: tqdm in /home/dj/anaconda3/envs/pointrix/lib/python3.10/site-packages (from iopath) (4.66.5)
# Requirement already satisfied: typing-extensions in /home/dj/anaconda3/envs/pointrix/lib/python3.10/site-packages (from iopath) (4.11.0)
# Collecting portalocker (from iopath)
#   Downloading portalocker-3.0.0-py3-none-any.whl.metadata (8.5 kB)
# Downloading portalocker-3.0.0-py3-none-any.whl (19 kB)
# Installing collected packages: portalocker, iopath
# Successfully installed iopath-0.1.10 portalocker-3.0.0
# Looking in links: https://dl.fbaipublicfiles.com/pytorch3d/packaging/wheels/py310_cu118_pyt210/download.html
# Collecting pytorch3d
#   Downloading https://dl.fbaipublicfiles.com/pytorch3d/packaging/wheels/py310_cu118_pyt210/pytorch3d-0.7.5-cp310-cp310-linux_x86_64.whl (20.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.1/20.1 MB 98.6 MB/s eta 0:00:00a 0:00:01
# INFO: pip is looking at multiple versions of pytorch3d to determine which version is compatible with other requirements. This could take a while.
# ERROR: Could not find a version that satisfies the requirement fvcore (from pytorch3d) (from versions: none)
# ERROR: No matching distribution found for fvcore
